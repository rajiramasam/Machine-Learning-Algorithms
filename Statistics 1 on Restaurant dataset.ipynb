# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('/content/drive/MyDrive/Datasets_ML/Restaurant.csv')

# %%
data.head()
# Out:
#        DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0  01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 1  01.10.23  23.40         174  OMLETTE       2.0  18.0       36.0   108.0
# 2  01.10.23  23.36         173     DOSA       3.0  20.0       60.0     NaN
# 3  01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 4  01.10.23  23.36         173   KALAKI       1.0  15.0       15.0   111.0
#
#    DAY
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
data.tail()
# Out:
#           DATE   TIME  INVOICE_NO            ITEM  QUANTITY   RATE  SUB_TOTAL  \
# 526  2.10.2285  21.53         146  VEG FRIED RICE       1.0   80.0       80.0
# 527  2.10.2286  21.53         145         PAROTTA       4.0   18.0       72.0
# 528  2.10.2287  21.53         147  BUTTER CHICKEN       1.0  130.0      130.0
# 529  2.10.2288  21.53         147         PAROTTA       2.0   18.0       36.0
# 530  2.10.2289  21.54         148         PAROTTA       3.0   18.0       54.0
#
#      AMOUNT  DAY
# 526    80.0    2
# 527    72.0    2
# 528     NaN    2
# 529   166.0    2
# 530    54.0    2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        531 non-null    object
#  1   TIME        531 non-null    float64
#  2   INVOICE_NO  531 non-null    int64
#  3   ITEM        531 non-null    object
#  4   QUANTITY    529 non-null    float64
#  5   RATE        530 non-null    float64
#  6   SUB_TOTAL   530 non-null    float64
#  7   AMOUNT      224 non-null    float64
#  8   DAY         531 non-null    int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 37.5+ KB

# %%
x=data[data['DATE']=='01.10.23']
x
# Out:
#          DATE   TIME  INVOICE_NO              ITEM  QUANTITY   RATE  \
# 0    01.10.23  23.40         174           PAROTTA       4.0   18.0
# 1    01.10.23  23.40         174           OMLETTE       2.0   18.0
# 2    01.10.23  23.36         173              DOSA       3.0   20.0
# 3    01.10.23  23.36         173           PAROTTA       2.0   18.0
# 4    01.10.23  23.36         173            KALAKI       1.0   15.0
# ..        ...    ...         ...               ...       ...    ...
# 254  01.10.23  12.36           7            KALAKI       1.0   15.0
# 255  01.10.23  12.15           5           PAROTTA       2.0   18.0
# 256  01.10.23  12.15           4  CHICKEN BIRIYANI       2.0  110.0
# 257  01.10.23  12.15           4    CHILLI CHICKEN       1.0  100.0
# 258  01.10.23  12.08           3         CHAPPATHI       3.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 0         72.0     NaN    1
# 1         36.0   108.0    1
# 2         60.0     NaN    1
# 3         36.0     NaN    1
# ...

# %%
x['AMOUNT'].mean()
# Out:
# np.float64(184.2280701754386)

# %%
x1=data[data['INVOICE_NO']==117]
x1
# Out:
#           DATE   TIME  INVOICE_NO                ITEM  QUANTITY   RATE  \
# 80    01.10.23  20.29         117          GHEE ROAST       2.0   50.0
# 81    01.10.23  20.29         117           EGG ROAST       2.0   50.0
# 82    01.10.23  20.29         117     CHICKEN NOODLES       1.0  100.0
# 83    01.10.23  20.29         117      CHILLI CHICKEN       1.0  100.0
# 84    01.10.23  20.29         117         COOL DRINKS       2.0   15.0
# 491  2.10.2250  21.00         117   SCHEZWAN EGG RICE       1.0   95.0
# 492  2.10.2251  21.00         117  CHICKEN FRIED RICE       1.0  100.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 80       100.0     NaN    1
# 81       100.0     NaN    1
# 82       100.0     NaN    1
# 83       100.0     NaN    1
# 84        30.0   430.0    1
# 491       95.0     NaN    2
# 492      100.0   195.0    2

# %%
x1['AMOUNT'].sum()
# Out:
# np.float64(625.0)

# %%
data['ITEM'].unique()
# Out:
# array(['PAROTTA', 'OMLETTE', 'DOSA', 'KALAKI', 'SCHEWAN CHICKEN RICE',
#        'BUN PAROTTA', 'VEG PULAV', 'CHAPPATHI', 'ONION ROAST',
#        'PODI ROAST', 'EGG VEECHU PAROTTA', 'PEPPER CHICKEN',
#        'PLAIN BIRIYANI', 'VEG FRIED RICE', 'PLAIN VEECHU PAROTTA',
#        'EGG BURJI MASALA', 'CHILLI GOBI', 'GHEE ROAST', 'CHICKEN ROAST',
#        'PODI DOSA', 'EGG DOSA', 'ONION UTTAPAM', 'UTHAPPAM',
#        'GILMA BIRIYANI', 'COOL DRINKS', 'EGG ROAST', 'CHETTINAD CHICKEN',
#        'MUTTON BIRIYANI', 'GOLI SODA', 'PRAWN PEPPER FRY',
#        'MUSHROOM PEPPER FRY', 'CHICKEN BIRIYANI', 'CHILLI CHICKEN',
#        'CHICKEN NOODLES', 'MUSHROOM CHIILI', 'MISCELLENOUS', 'ROAST',
#        'CHICKEN FRIED RICE', 'EGG MASALA', 'PEPPER CHICKEN MASALA',
#        'CHICKEN LOLIPOP(5 PCS)', 'LOLLIPOP', 'MUTTON FRY',
#        'CHICKEN LAPPA', 'EGG FRIED RICE', 'MUSHROOM MASALA',
#        'CHICKEN FRY', 'MUSHROOM MANCHURIAN', 'GOBI FRIED RICE', 'GOBI 65',
# ...

# %%
df=pd.DataFrame(data)

# %%
b=df.groupby('ITEM')['SUB_TOTAL'].sum().sort_values(ascending=False).head(5)

# %%
b
# Out:
# ITEM
# PAROTTA             5346.0
# CHICKEN BIRIYANI    5060.0
# MUTTON BIRIYANI     2550.0
# PLAIN BIRIYANI      2240.0
# DOSA                2160.0
# Name: SUB_TOTAL, dtype: float64

# %%
plt.bar(b.index,b.values)
plt.xlabel(xlabel='Item')
plt.ylabel(ylabel='Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
c=df.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=False).head(5)
c
# Out:
# ITEM
# PAROTTA             297.0
# DOSA                108.0
# CHAPPATHI            50.0
# KALAKI               49.0
# CHICKEN BIRIYANI     46.0
# Name: QUANTITY, dtype: float64

# %%
plt.bar(c.index,c.values)
# Out:
# <BarContainer object of 5 artists>

# %%
y=data[data['DATE']=='2.10.2023']
y
# Out:
#           DATE   TIME  INVOICE_NO               ITEM  QUANTITY   RATE  \
# 259  2.10.2023  12.29           1   CHICKEN BIRIYANI       1.0  110.0
# 260  2.10.2023  12.32           2  CHICKEN FICE RICE       1.0  100.0
# 261  2.10.2023  12.32           2            GOBI 65       1.0   60.0
# 262  2.10.2023  12.32           2        EGG PAROTTA       1.0   70.0
# 263  2.10.2023  12.34           3            PAROTTA      12.0   18.0
# 264  2.10.2023  12.34           3       EGG BIRIYANI       1.0   80.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 259      110.0   110.0    2
# 260      100.0   230.0    2
# 261       60.0     NaN    2
# 262       70.0     NaN    2
# 263      216.0   296.0    2
# 264       80.0     NaN    2

# %%
dd=pd.DataFrame(y)
y1=dd.groupby('ITEM')['QUANTITY'].sum().sort_values()
y1
# Out:
# ITEM
# CHICKEN BIRIYANI      1.0
# CHICKEN FICE RICE     1.0
# EGG BIRIYANI          1.0
# EGG PAROTTA           1.0
# GOBI 65               1.0
# PAROTTA              12.0
# Name: QUANTITY, dtype: float64

# %%
val=y1.values.min()
val
# Out:
# np.float64(1.0)

# %%
y2=y1[y1==val]

# %%
plt.bar(y2.index,y2.values)
# Out:
# <BarContainer object of 5 artists>

# %%
i=data.groupby('INVOICE_NO')['AMOUNT'].sum().sort_values(ascending=False)
va=i.values.max()
i2=i[i==va]

# %%
i2
# Out:
# INVOICE_NO
# 63    941.0
# Name: AMOUNT, dtype: float64

# %%
data['TIME'].unique()
# Out:
# array([23.4 , 23.36, 23.27, 19.42, 20.42, 19.53, 22.46, 22.45, 23.24,
#        15.34, 23.16, 23.  , 22.57, 22.52, 22.27, 22.42, 22.36, 22.35,
#        22.26, 22.1 , 22.14, 21.55, 22.06, 22.04, 21.52, 21.47, 21.33,
#        21.17, 21.11, 21.05, 20.53, 20.56, 20.55, 20.33, 20.29, 20.19,
#        20.13, 20.1 , 20.09, 20.02, 19.49, 19.48, 19.47, 19.25, 19.22,
#        19.09, 19.06, 19.37, 18.  , 17.47, 17.33, 17.17, 16.53, 16.52,
#        16.36, 16.24, 16.16, 16.1 , 16.08, 16.07, 16.04, 15.56, 15.5 ,
#        15.46, 15.45, 15.23, 15.12, 15.21, 14.23, 15.27, 15.25, 15.1 ,
#        15.04, 15.01, 14.57, 14.53, 14.52, 14.49, 14.45, 14.41, 14.4 ,
#        14.37, 13.52, 14.26, 14.18, 13.49, 14.03, 13.58, 13.54, 13.46,
#        13.45, 13.39, 13.38, 13.23, 13.2 , 13.18, 13.17, 13.08, 13.04,
#        13.03, 13.01, 12.5 , 12.36, 12.15, 12.08, 12.29, 12.32, 12.34,
#        12.45, 12.48, 12.52, 13.16, 13.21, 13.22, 13.44, 13.34, 13.59,
# ...

# %%
f=data[data['DATE']=='01.10.23']
f1=f[f['ITEM']=='PAROTTA']
f1
# Out:
#          DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0    01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 3    01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 5    01.10.23  23.27         172  PAROTTA       6.0  18.0      108.0     NaN
# 17   01.10.23  23.24         170  PAROTTA       1.0  18.0       18.0     NaN
# 19   01.10.23  15.34          68  PAROTTA      44.0  18.0      792.0   792.0
# 30   01.10.23  22.52         162  PAROTTA       3.0  18.0       54.0   314.0
# 42   01.10.23  22.35         153  PAROTTA       4.0  18.0       72.0    72.0
# 49   01.10.23  22.14         146  PAROTTA       1.0  18.0       18.0     NaN
# 55   01.10.23  21.52         140  PAROTTA       6.0  18.0      108.0     NaN
# 65   01.10.23  21.05         129  PAROTTA       2.0  18.0       36.0    36.0
# 72   01.10.23  20.56         126  PAROTTA       5.0  18.0       90.0    90.0
# ...

# %%
f2=f1.groupby('TIME')['QUANTITY'].sum()
f2
# Out:
# TIME
# 12.15     2.0
# 12.36     3.0
# 13.01     2.0
# 13.03     5.0
# 13.08     5.0
# 13.17     2.0
# 13.18     2.0
# 13.54     4.0
# 14.23     1.0
# 14.40     2.0
# 14.49     2.0
# 14.57     3.0
# 15.21     2.0
# 15.34    48.0
# 15.46     2.0
# 15.50     2.0
# 16.04     2.0
# 16.07     2.0
# 16.08     1.0
# 16.52     2.0
# 19.22     5.0
# 19.42     6.0
# 19.48     1.0
# 19.49     4.0
# 20.02     5.0
# 20.09     2.0
# 20.10     2.0
# 20.19     4.0
# 20.56     5.0
# 21.05     2.0
# 21.52     6.0
# 22.14     1.0
# 22.35     4.0
# 22.52     3.0
# 23.24     1.0
# 23.27     6.0
# 23.36     2.0
# 23.40     4.0
# Name: QUANTITY, dtype: float64

# %%
f3=f2[(f2.index>=16.00) & (f2.index<=21.00)]
f3.values.sum()
# Out:
# np.float64(41.0)
